# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/설윤.jpg')
print(img.shape)
gimg1=cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
print(gimg1.shape)
#plt.imshow(gimg1, cmap='gray')
cv2_imshow(gimg1)
# Out:
# (651, 500, 3)
# (651, 500)
# <PIL.Image.Image image mode=L size=500x651>

# %%
def saturation(val):
  if val > 255:
    return 255
  elif val < 0:
    return 0
  else:
    return val

# %%
kernel3 = np.ones((3,3),np.float32)/9
kernel5 = np.ones((5,5),np.float32)/25
kernel7 = np.ones((7,7),np.float32)/49

# %%
output =cv2.filter2D(gimg1,-1,kernel5)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=500x651>

# %%
output = cv2.filter2D(gimg1,-1,kernel3)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=500x651>

# %%
output = cv2.GaussianBlur(gimg1, (7, 7), 1)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=500x651>

# %%
output = cv2.medianBlur(gimg1, 11)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=500x651>

# %%
outimage = gimg1.copy()
#blurImage = cv2.GaussianBlur(outimage, (7,7), 5)


x = 200 + 70
y = 200 + 65
size = 15

for h in range(y, y+size):
  for w in range(x, x+size):
    outimage[h][w] = 255

cv2_imshow(outimage)
# Out:
# <PIL.Image.Image image mode=L size=500x651>

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/설윤.jpg')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
cv2_imshow(gimg1)
# Out:
# (651, 500, 3)
# <PIL.Image.Image image mode=L size=500x651>

# %%
outimg = cv2.GaussianBlur(gimg1, (7,7), 2)
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=500x651>

# %%
edgeImage = cv2.addWeighted(gimg1, 1, outimg, -1, 0)
cv2_imshow(edgeImage)
# Out:
# <PIL.Image.Image image mode=L size=500x651>

# %%
unsharpImage = cv2.addWeighted(gimg1, 1, edgeImage, 2, 0)
cv2_imshow(unsharpImage)
# Out:
# <PIL.Image.Image image mode=L size=500x651>

# %%
kernel3 = np.ones((3,3), np.float32)/9
kernel3[0][0] = -1/9
kernel3[0][1] = -1/9
kernel3[0][2] = -1/9
kernel3[1][0] = -1/9
kernel3[1][1] = 17/9
kernel3[1][2] = -1/9
kernel3[2][0] = -1/9
kernel3[2][1] = -1/9
kernel3[2][2] = -1/9
print(kernel3)
# Out:
# [[-0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111  1.8888888  -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111]]

# %%
output = cv2.filter2D(gimg1,-1,kernel3)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=500x651>
